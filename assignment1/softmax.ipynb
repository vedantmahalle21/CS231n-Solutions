# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.390815
# sanity check: 2.302585

# %% [markdown]
# **Inline Question 1**
#
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# $\color{blue}{\textit Your Answer:}$ *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -1.589404 analytic: -1.589404, relative error: 4.665566e-09
# numerical: -1.542255 analytic: -1.542255, relative error: 1.118463e-09
# numerical: 1.179548 analytic: 1.179548, relative error: 3.438836e-08
# numerical: -5.865417 analytic: -5.865417, relative error: 6.185331e-09
# numerical: -0.973898 analytic: -0.973898, relative error: 6.482844e-09
# numerical: 1.451104 analytic: 1.451104, relative error: 3.850604e-09
# numerical: 1.329225 analytic: 1.329225, relative error: 4.288011e-09
# numerical: 1.192459 analytic: 1.192459, relative error: 1.830579e-08
# numerical: -0.419326 analytic: -0.419326, relative error: 4.098378e-08
# numerical: -0.005493 analytic: -0.005493, relative error: 1.640806e-05
# numerical: 2.185671 analytic: 2.185671, relative error: 1.692121e-08
# numerical: 3.282689 analytic: 3.282689, relative error: 5.313010e-09
# numerical: 0.293319 analytic: 0.293319, relative error: 2.559285e-07
# numerical: -0.261171 analytic: -0.261171, relative error: 2.712157e-08
# numerical: 0.006782 analytic: 0.006782, relative error: 6.439290e-07
# numerical: 2.752209 analytic: 2.752209, relative error: 2.215164e-08
# numerical: 1.217739 analytic: 1.217739, relative error: 2.819495e-08
# numerical: 1.584019 analytic: 1.584019, relative error: 3.089691e-08
# numerical: -3.014790 analytic: -3.014790, relative error: 7.132000e-09
# numerical: 1.569328 analytic: 1.569328, relative error: 4.583333e-09

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.390815e+00 computed in 0.158865s
# vectorized loss: 2.390815e+00 computed in 0.007304s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 5e-7, 3e-7, 2e-7, 4e-7, 6e-6]
regularization_strengths = [1.25e4, 2.5e4, 5e4, 3e4, 4e4, 5e5]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

for l_r in learning_rates:
  for r_s in regularization_strengths:
    svm_1 = Softmax()
    loss_h = svm_1.train(X_train, y_train, learning_rate=l_r, reg=r_s,
                         num_iters=500, verbose=True)
    y_train_pred1 = svm_1.predict(X_train)
    trainu = np.mean(y_train == y_train_pred1)
    
    y_val_pred1 = svm_1.predict(X_val)
    valu = np.mean(y_val == y_val_pred1)
    
    results[(l_r, r_s)] = (trainu, valu)
    if valu> best_val:
      best_val = valu
      best_softmax = svm_1

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 500: loss 392.364665
# iteration 100 / 500: loss 237.533715
# iteration 200 / 500: loss 144.371662
# iteration 300 / 500: loss 88.066289
# iteration 400 / 500: loss 54.095229
# iteration 0 / 500: loss 761.790900
# iteration 100 / 500: loss 279.627816
# iteration 200 / 500: loss 103.545656
# iteration 300 / 500: loss 39.163715
# iteration 400 / 500: loss 15.678801
# iteration 0 / 500: loss 1546.522515
# iteration 100 / 500: loss 208.135518
# iteration 200 / 500: loss 29.710865
# iteration 300 / 500: loss 5.779746
# iteration 400 / 500: loss 2.606358
# iteration 0 / 500: loss 919.596594
# iteration 100 / 500: loss 276.397217
# iteration 200 / 500: loss 84.221402
# iteration 300 / 500: loss 26.697314
# iteration 400 / 500: loss 9.454535
# iteration 0 / 500: loss 1224.641404
# iteration 100 / 500: loss 246.361268
# iteration 200 / 500: loss 50.906437
# iteration 300 / 500: loss 11.884582
# iteration 400 / 500: loss 4.137938
# iteration 0 / 500: loss 15130.381828
# iteration 100 / 500: loss 2.255739
# iteration 200 / 500: loss 2.261176
# iteration 300 / 500: loss 2.269242
# iteration 400 / 500: loss 2.283444
# iteration 0 / 500: loss 389.202383
# iteration 100 / 500: loss 32.887468
# iteration 200 / 500: loss 4.534929
# iteration 300 / 500: loss 2.191768
# iteration 400 / 500: loss 2.042799
# iteration 0 / 500: loss 779.798440
# iteration 100 / 500: loss 6.945288
# iteration 200 / 500: loss 2.136446
# iteration 300 / 500: loss 2.104114
# iteration 400 / 500: loss 2.120511
# iteration 0 / 500: loss 1551.348336
# iteration 100 / 500: loss 2.196162
# iteration 200 / 500: loss 2.116346
# iteration 300 / 500: loss 2.133076
# iteration 400 / 500: loss 2.158073
# iteration 0 / 500: loss 938.698898
# iteration 100 / 500: loss 4.258760
# iteration 200 / 500: loss 2.067301
# iteration 300 / 500: loss 2.137872
# iteration 400 / 500: loss 2.068274
# iteration 0 / 500: loss 1226.780786
# iteration 100 / 500: loss 2.487934
# iteration 200 / 500: loss 2.124034
# iteration 300 / 500: loss 2.135971
# iteration 400 / 500: loss 2.140478
# iteration 0 / 500: loss 15257.722133
# iteration 100 / 500: loss 2.268437
# iteration 200 / 500: loss 2.283405
# iteration 300 / 500: loss 2.264730
# iteration 400 / 500: loss 2.276814
# iteration 0 / 500: loss 390.971340
# iteration 100 / 500: loss 87.342125
# iteration 200 / 500: loss 20.859349
# iteration 300 / 500: loss 6.131149
# iteration 400 / 500: loss 2.894365
# iteration 0 / 500: loss 766.713373
# iteration 100 / 500: loss 38.888319
# iteration 200 / 500: loss 3.862743
# iteration 300 / 500: loss 2.197343
# iteration 400 / 500: loss 2.007497
# iteration 0 / 500: loss 1528.455323
# iteration 100 / 500: loss 5.590561
# iteration 200 / 500: loss 2.159433
# iteration 300 / 500: loss 2.111728
# iteration 400 / 500: loss 2.125072
# iteration 0 / 500: loss 925.099790
# iteration 100 / 500: loss 26.272413
# iteration 200 / 500: loss 2.778328
# iteration 300 / 500: loss 2.157428
# iteration 400 / 500: loss 2.136696
# iteration 0 / 500: loss 1257.352812
# iteration 100 / 500: loss 11.809288
# iteration 200 / 500: loss 2.191247
# iteration 300 / 500: loss 2.118521
# iteration 400 / 500: loss 2.159492
# iteration 0 / 500: loss 15363.698464
# iteration 100 / 500: loss 2.269916
# iteration 200 / 500: loss 2.268643
# iteration 300 / 500: loss 2.273006
# iteration 400 / 500: loss 2.278321
# iteration 0 / 500: loss 388.077488
# iteration 100 / 500: loss 142.248878
# iteration 200 / 500: loss 53.201997
# iteration 300 / 500: loss 20.762444
# iteration 400 / 500: loss 8.888450
# iteration 0 / 500: loss 776.755734
# iteration 100 / 500: loss 105.191325
# iteration 200 / 500: loss 15.818012
# iteration 300 / 500: loss 3.943343
# iteration 400 / 500: loss 2.274118
# iteration 0 / 500: loss 1544.344966
# iteration 100 / 500: loss 29.113304
# iteration 200 / 500: loss 2.604583
# iteration 300 / 500: loss 2.176621
# iteration 400 / 500: loss 2.101569
# iteration 0 / 500: loss 932.081621
# iteration 100 / 500: loss 84.643930
# iteration 200 / 500: loss 9.437618
# iteration 300 / 500: loss 2.772642
# iteration 400 / 500: loss 2.189154
# iteration 0 / 500: loss 1236.257259
# iteration 100 / 500: loss 50.813304
# iteration 200 / 500: loss 4.087748
# iteration 300 / 500: loss 2.218320
# iteration 400 / 500: loss 2.134536
# iteration 0 / 500: loss 15193.905660
# iteration 100 / 500: loss 2.255834
# iteration 200 / 500: loss 2.275965
# iteration 300 / 500: loss 2.267227
# iteration 400 / 500: loss 2.275789
# iteration 0 / 500: loss 398.548713
# iteration 100 / 500: loss 54.329913
# iteration 200 / 500: loss 8.967978
# iteration 300 / 500: loss 3.019683
# iteration 400 / 500: loss 2.167151
# iteration 0 / 500: loss 775.477521
# iteration 100 / 500: loss 15.510596
# iteration 200 / 500: loss 2.365179
# iteration 300 / 500: loss 2.064691
# iteration 400 / 500: loss 2.043179
# iteration 0 / 500: loss 1543.499561
# iteration 100 / 500: loss 2.566686
# iteration 200 / 500: loss 2.171972
# iteration 300 / 500: loss 2.133163
# iteration 400 / 500: loss 2.117785
# iteration 0 / 500: loss 926.376613
# iteration 100 / 500: loss 9.212183
# iteration 200 / 500: loss 2.228713
# iteration 300 / 500: loss 2.137962
# iteration 400 / 500: loss 2.096333
# iteration 0 / 500: loss 1222.976617
# iteration 100 / 500: loss 3.947916
# iteration 200 / 500: loss 2.173607
# iteration 300 / 500: loss 2.168211
# iteration 400 / 500: loss 2.167180
# iteration 0 / 500: loss 15512.914694
# iteration 100 / 500: loss 2.277448
# iteration 200 / 500: loss 2.279354
# iteration 300 / 500: loss 2.267784
# iteration 400 / 500: loss 2.277759
# iteration 0 / 500: loss 389.516005
# iteration 100 / 500: loss 2.442698
# iteration 200 / 500: loss 2.610350
# iteration 300 / 500: loss 3.155242
# iteration 400 / 500: loss 2.352790
# iteration 0 / 500: loss 764.798796
# iteration 100 / 500: loss 3.034754
# iteration 200 / 500: loss 2.585607
# iteration 300 / 500: loss 3.634310
# iteration 400 / 500: loss 2.852469
# iteration 0 / 500: loss 1548.489991
# iteration 100 / 500: loss 4.587514
# iteration 200 / 500: loss 4.690184
# iteration 300 / 500: loss 4.555408
# iteration 400 / 500: loss 4.131722
# iteration 0 / 500: loss 934.009850
# iteration 100 / 500: loss 4.432264
# iteration 200 / 500: loss 4.640268
# iteration 300 / 500: loss 3.711674
# iteration 400 / 500: loss 2.880200
# iteration 0 / 500: loss 1217.282732
# iteration 100 / 500: loss 4.587238
# iteration 200 / 500: loss 4.471593
# iteration 300 / 500: loss 3.495862
# iteration 400 / 500: loss 4.720994
# iteration 0 / 500: loss 15261.420777
# /content/gdrive/My Drive/Colab Notebooks/assignment1/cs231n/classifiers/softmax.py:88: RuntimeWarning: divide by zero encountered in log
#   loss = np.sum(-np.log(p[np.arange(num_train), y]))
# iteration 100 / 500: loss inf
# iteration 200 / 500: loss inf
# /content/gdrive/My Drive/Colab Notebooks/assignment1/cs231n/classifiers/softmax.py:91: RuntimeWarning: overflow encountered in double_scalars
#   loss +=  reg * np.sum(W * W)
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /content/gdrive/My Drive/Colab Notebooks/assignment1/cs231n/classifiers/softmax.py:91: RuntimeWarning: overflow encountered in multiply
#   loss +=  reg * np.sum(W * W)
# iteration 300 / 500: loss inf
# iteration 400 / 500: loss inf
# /content/gdrive/My Drive/Colab Notebooks/assignment1/cs231n/classifiers/softmax.py:97: RuntimeWarning: overflow encountered in multiply
#   dW += 2*reg*W
# lr 1.000000e-07 reg 1.250000e+04 train accuracy: 0.269592 val accuracy: 0.275000
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.309122 val accuracy: 0.319000
# lr 1.000000e-07 reg 3.000000e+04 train accuracy: 0.311469 val accuracy: 0.330000
# lr 1.000000e-07 reg 4.000000e+04 train accuracy: 0.314286 val accuracy: 0.327000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.307816 val accuracy: 0.322000
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.260429 val accuracy: 0.274000
# lr 2.000000e-07 reg 1.250000e+04 train accuracy: 0.339367 val accuracy: 0.353000
# lr 2.000000e-07 reg 2.500000e+04 train accuracy: 0.327469 val accuracy: 0.351000
# lr 2.000000e-07 reg 3.000000e+04 train accuracy: 0.320490 val accuracy: 0.338000
# lr 2.000000e-07 reg 4.000000e+04 train accuracy: 0.308571 val accuracy: 0.328000
# lr 2.000000e-07 reg 5.000000e+04 train accuracy: 0.303327 val accuracy: 0.317000
# lr 2.000000e-07 reg 5.000000e+05 train accuracy: 0.273694 val accuracy: 0.284000
# lr 3.000000e-07 reg 1.250000e+04 train accuracy: 0.344551 val accuracy: 0.359000
# lr 3.000000e-07 reg 2.500000e+04 train accuracy: 0.329347 val accuracy: 0.346000
# lr 3.000000e-07 reg 3.000000e+04 train accuracy: 0.323082 val accuracy: 0.332000
# lr 3.000000e-07 reg 4.000000e+04 train accuracy: 0.317143 val accuracy: 0.318000
# lr 3.000000e-07 reg 5.000000e+04 train accuracy: 0.295082 val accuracy: 0.306000
# lr 3.000000e-07 reg 5.000000e+05 train accuracy: 0.265020 val accuracy: 0.277000
# lr 4.000000e-07 reg 1.250000e+04 train accuracy: 0.345653 val accuracy: 0.364000
# lr 4.000000e-07 reg 2.500000e+04 train accuracy: 0.324469 val accuracy: 0.347000
# lr 4.000000e-07 reg 3.000000e+04 train accuracy: 0.322408 val accuracy: 0.327000
# lr 4.000000e-07 reg 4.000000e+04 train accuracy: 0.309367 val accuracy: 0.329000
# lr 4.000000e-07 reg 5.000000e+04 train accuracy: 0.317510 val accuracy: 0.333000
# lr 4.000000e-07 reg 5.000000e+05 train accuracy: 0.231735 val accuracy: 0.242000
# lr 5.000000e-07 reg 1.250000e+04 train accuracy: 0.346490 val accuracy: 0.354000
# lr 5.000000e-07 reg 2.500000e+04 train accuracy: 0.324122 val accuracy: 0.331000
# lr 5.000000e-07 reg 3.000000e+04 train accuracy: 0.320878 val accuracy: 0.340000
# lr 5.000000e-07 reg 4.000000e+04 train accuracy: 0.309449 val accuracy: 0.322000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.301245 val accuracy: 0.299000
# lr 5.000000e-07 reg 5.000000e+05 train accuracy: 0.244673 val accuracy: 0.248000
# lr 6.000000e-06 reg 1.250000e+04 train accuracy: 0.184245 val accuracy: 0.189000
# lr 6.000000e-06 reg 2.500000e+04 train accuracy: 0.195163 val accuracy: 0.218000
# lr 6.000000e-06 reg 3.000000e+04 train accuracy: 0.210041 val accuracy: 0.224000
# lr 6.000000e-06 reg 4.000000e+04 train accuracy: 0.152408 val accuracy: 0.150000
# lr 6.000000e-06 reg 5.000000e+04 train accuracy: 0.081306 val accuracy: 0.085000
# lr 6.000000e-06 reg 5.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.364000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.357000

# %% [markdown]
# **Inline Question 2** - *True or False*
#
# Suppose the overall training loss is defined as the sum of the per-datapoint loss over all training examples. It is possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# $\color{blue}{\textit Your Answer:}$
#
#
# $\color{blue}{\textit Your Explanation:}$

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])

# %%
    loss = 0.0
    dW = np.zeros_like(W)
    num_classes = W.shape[1]
    num_train = X_dev.shape[0]
    reg = .001

    #############################################################################
    # TODO: Compute the softmax loss and its gradient using no explicit loops.  #
    # Store the loss in loss and the gradient in dW. If you are not careful     #
    # here, it is easy to run into numeric instability. Don't forget the        #
    # regularization!                                                           #
    #############################################################################
    # *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

    scores = X_dev.dot(W)
    print(scores.shape)
    scores -= np.matrix(np.max(scores, axis = 1)).T
    print(scores.shape)
    scores_i = -scores[np.arange(num_train), y_dev]
    print(scores_i.shape)
    scores1 = np.sum(np.exp(scores), axis=1)
    #scores_i = np.exp(scores_i)
    print(scores1.shape)
    loss1 = np.log(scores1)
    #print(loss.shape)
    loss += loss1 + scores_i
    #print(loss.shape)
    loss /= num_train
    #print(loss.shape)
    loss +=  reg * np.sum(W * W)
    np.sum(loss)
    print(loss)

    dW1 = np.exp(scores) / np.matrix(scores1).T
    print(dW1.shape)
    dW1[np.arange(num_train), y_dev] -= 1
    print(dW1.shape)
    dW = X_dev.T.dot(dW1)
    print(dW.shape)
    dW /= num_train
    print(dW.shape)
    dW += 2*reg*W
    print(dW.shape)
# Out:
# (500, 10)
# (500, 10)
# (500,)
# ()
# [0.01623057 0.01736773 0.01620576 0.01769321 0.01624767 0.01661933
#  0.01746256 0.01693122 0.01626096 0.01656222 0.01737091 0.01703963
#  0.01733946 0.01749492 0.01687049 0.01762787 0.01620576 0.01620576
#  0.01672324 0.01814724 0.01787315 0.01650914 0.01694052 0.01690768
#  0.01774105 0.0165275  0.01620576 0.01900296 0.01692646 0.01785248
#  0.01684626 0.0170432  0.01653762 0.01643221 0.01698559 0.01630199
#  0.01732758 0.01662863 0.01803179 0.01886127 0.01946241 0.01620576
#  0.01832218 0.01780426 0.01652862 0.01835597 0.01697364 0.01620576
#  0.01716344 0.01713682 0.01740846 0.01741364 0.01710664 0.01656328
#  0.0162322  0.0167095  0.01723542 0.01620576 0.01664615 0.01672753
#  0.01640356 0.01728286 0.01620576 0.01716264 0.01620576 0.01782151
#  0.01668072 0.01684971 0.0177074  0.01745713 0.01734566 0.01761706
#  0.01629257 0.01705983 0.01661199 0.01654306 0.01777008 0.01627763
#  0.01789312 0.01637874 0.01705725 0.0164266  0.01620576 0.01765412
#  0.01680093 0.01720147 0.01679234 0.01841892 0.01670675 0.01746628
#  0.01763014 0.01735933 0.0176591  0.01677294 0.01822825 0.01743758
#  0.01672317 0.01782842 0.01670232 0.01761847 0.01683017 0.01647083
#  0.01631678 0.01743212 0.01672944 0.01825979 0.01756557 0.01620576
#  0.01917336 0.01620576 0.01695221 0.01734394 0.0170741  0.01699364
#  0.01746339 0.0169537  0.01647558 0.01679503 0.01675657 0.01912354
#  0.01836287 0.01620576 0.01756333 0.01677181 0.01713485 0.01704232
#  0.01707398 0.01819215 0.01743488 0.01768926 0.01856078 0.01809241
#  0.01646179 0.01639983 0.01708973 0.01713386 0.01644127 0.01718888
#  0.01781374 0.0172322  0.01737493 0.01793753 0.01665777 0.01789722
#  0.01719273 0.01651662 0.01771387 0.01620576 0.0170507  0.01737735
#  0.01624199 0.01758501 0.01746064 0.01646276 0.01717192 0.01739732
#  0.01718411 0.01740888 0.01620576 0.01658502 0.01727925 0.0168873
#  0.0164052  0.01677456 0.01700382 0.01761338 0.01699141 0.01673714
#  0.01692953 0.01620576 0.0177377  0.01682839 0.01620576 0.01802347
#  0.01620576 0.01708267 0.01697494 0.01726137 0.01651082 0.01712203
#  0.01678939 0.01720468 0.01704401 0.01766204 0.01655175 0.01685475
#  0.01861696 0.01678918 0.01703692 0.01647125 0.01681841 0.01702693
#  0.01625184 0.01706054 0.01620576 0.01761437 0.01620576 0.01791781
#  0.01684006 0.01733196 0.0194315  0.01673711 0.0170222  0.01713271
#  0.01870916 0.01633321 0.01797123 0.01690857 0.01742502 0.01716349
#  0.01635438 0.01620576 0.0172519  0.01665587 0.01799443 0.01745715
#  0.0178904  0.01752524 0.01647455 0.01700268 0.01760575 0.01685647
#  0.01677378 0.01880747 0.01666424 0.01827392 0.01662111 0.01787179
#  0.01763479 0.01760495 0.01714048 0.01792443 0.01739178 0.01674039
#  0.0172693  0.01670753 0.01654345 0.01704952 0.01620576 0.01726744
#  0.01680975 0.01890464 0.01902684 0.01700153 0.0167747  0.01654665
#  0.0179137  0.01691106 0.01662716 0.01620576 0.0171795  0.0180096
#  0.01620576 0.01851391 0.01655219 0.01681253 0.01687652 0.01718008
#  0.01794317 0.01650633 0.0175576  0.01717127 0.01620576 0.01666428
#  0.01833419 0.01686982 0.01642578 0.0172145  0.01772016 0.01657056
#  0.01765838 0.01875212 0.0174012  0.01816025 0.01658034 0.01788305
#  0.01620576 0.0177485  0.0162272  0.01750436 0.01639679 0.0179222
#  0.01661594 0.01662075 0.01660344 0.01667793 0.01704152 0.01714795
#  0.01710735 0.0163806  0.01898738 0.01854877 0.01658074 0.01711065
#  0.01665854 0.01638749 0.01796041 0.01706263 0.01620576 0.01712413
#  0.01714787 0.01735654 0.01697851 0.01743466 0.01623986 0.01620576
#  0.01620576 0.01620576 0.01870202 0.01646864 0.01851928 0.01628258
#  0.01620907 0.01655424 0.01700258 0.01707116 0.01620576 0.01686554
#  0.01755892 0.01726531 0.01713035 0.01697157 0.01702066 0.01681434
#  0.01670349 0.01775417 0.01744658 0.01866881 0.01787117 0.01672254
#  0.01883327 0.018216   0.01643413 0.0164894  0.01620576 0.01728039
#  0.01671451 0.01700063 0.0181272  0.01783131 0.01787172 0.01772843
#  0.01647296 0.01687582 0.01620576 0.01665083 0.01651832 0.01817958
#  0.01669949 0.01750466 0.01680721 0.01668034 0.0176889  0.01657241
#  0.01620576 0.01828344 0.01824833 0.01620576 0.01648966 0.01668625
#  0.0174291  0.01717691 0.01651728 0.01620576 0.0164783  0.01680474
#  0.01788137 0.01633026 0.0170444  0.01755685 0.01620576 0.01772875
#  0.01690593 0.0172014  0.01751011 0.01653053 0.01701941 0.01844449
#  0.01634989 0.01697533 0.01734991 0.01730388 0.01629713 0.01739532
#  0.01685268 0.01730818 0.01734049 0.01685388 0.01771256 0.01625206
#  0.01741034 0.01621409 0.01745583 0.01687174 0.01689508 0.01745595
#  0.01954956 0.0169822  0.01718272 0.0181767  0.01654471 0.01645435
#  0.01823628 0.01620576 0.01853189 0.01721435 0.01747366 0.01620576
#  0.01798546 0.01683758 0.01687809 0.01751964 0.01719428 0.01698967
#  0.01861972 0.01823764 0.01655997 0.01714261 0.01620576 0.01769578
#  0.01620576 0.01705992 0.01718295 0.01738545 0.01620576 0.01678524
#  0.01809318 0.01620576 0.01862352 0.01696325 0.01635624 0.0173904
#  0.01735038 0.01850757 0.01757993 0.01730267 0.01621208 0.01684104
#  0.01791712 0.01685545 0.01739885 0.01620576 0.01665936 0.01630002
#  0.01667712 0.01620576 0.01799928 0.01786661 0.01766564 0.01694119
#  0.01620576 0.01770427 0.01623664 0.01620576 0.01654067 0.01710132
#  0.01636133 0.01653182 0.01831919 0.01805879 0.01620576 0.01788479
#  0.01750217 0.01775138 0.01828454 0.01826031 0.01641406 0.01710354
#  0.01620576 0.01671223 0.01636397 0.019677   0.01726976 0.01706392
#  0.01661707 0.01761973 0.01762525 0.01765039 0.01629938 0.01706585
#  0.01640987 0.01774042 0.01677346 0.01695809 0.01757538 0.01690128
#  0.01811492 0.01620576 0.01735372 0.0173772  0.01677745 0.01738681
#  0.01832828 0.01671627 0.01710534 0.01704638 0.01776164 0.01797534
#  0.01692355 0.01665087]
# (500, 10)
# (500, 10)
# (3073, 10)
# (3073, 10)
# (3073, 10)
